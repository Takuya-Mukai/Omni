# %% [markdown]
# # **Python基礎　練習問題集**

# %% [markdown]
# # **算術演算子、比較演算子（資料「2. Pythonの基礎・実践」 p.4-8）**

# %% [markdown]
# 問1-1. 以下のコードを書き写して、結果を確認してください。
#
#
# ```
# 1 * 2
# ```
# ```
# 4 / 2
# ```

# %%
# 以下に書き写してください

# %%
# 以下に書き写してください

# %% [markdown]
# 問1-2. 以下の？を書き換えて3を出力してください。

# %%
1 ？ 2
# Out:
# 3

# %%
6 ？ 3
# Out:
# 3

# %% [markdown]
# 問1-3. 以下の選択肢からTrueになる答えを選んでください。
#
# 選択肢 1
#
# ```
# 1 >= 0
# ```
# 選択肢 2
#
# ```
# 1 <= 0
# ```
# 選択肢 3
#
# ```
# 1 == 0
# ```
# 選択肢 4
#
# ```
# 1 != 0
# ```

# %%
#答え

# %% [markdown]
# 発展問題　コードを書いてみましょう😊！
#
# 問1-4a. べき乗を使って、出力が16になるコードを書いてください。
#
# 問1-4b. 「左右の値が同じ」と評価する比較演算子を使用して、Trueを出力するコードを書いてください。

# %%
#問1-4aの答えを以下に書いてください

# %%
#問1-4bの答えを以下に書いてください

# %% [markdown]
# ☕Break Time☕
#
# ここまでお疲れ様でした！
# これまで内容で不明点がある方は是非復習して知識を定着していきましょう！

# %% [markdown]
# # **変数、データ型（資料「2. Pythonの基礎・実践」 p.9-12）**

# %% [markdown]
# 問2-1. コードを書き写して、結果を確認してください。
#
# ```
# x = 2
# x
# ```
# ```
# x = x + 2
# x
# ```
# ```
# y = x / 10
# type (y)
# ```

# %%
# 以下に書き写してください

# %%
# 以下に書き写してください

# %%
# 以下に書き写してください

# %% [markdown]
# 問2-2. 以下のコードの一部を書き換えて文字列(str)を出力してください。

# %%
x = 1
type (x)
# Out:
# int

# %%
#コードを書き直して実行して、str(文字列)と出力してください。
x = 1
type (x)

# %% [markdown]
# 問2-3. 以下のコードを実行した結果として、正しい選択肢を選んでください。
#
#
#
# ```
# y = 2
# z = y > 1
# type (z)
# ```
#
# 選択肢1.　int
#
# 選択肢2.　float
#
# 選択肢3.　bool

# %%
#答え

# %% [markdown]
# 発展問題　コードを書いてみましょう😊！
#
# 問2-4a. 変数を使ったコードを書いてください。
#
# 問2-4b. データ型を確認するコードを書いてください。

# %%
#問2-4aの答えを以下に書いてください

# %%
#問2-4bの答えを以下に書いてください

# %% [markdown]
# ☕Break Time☕
#
# ここまでお疲れ様でした！ これまでの内容で不明点がある方は是非復習して知識を定着していきましょう！
#
# 今回の練習問題は以上です。また次回の挑戦をお待ちしております。
